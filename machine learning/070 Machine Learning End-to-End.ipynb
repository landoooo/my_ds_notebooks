# %% [markdown]
# # Presenting the case study
#
# Predicting heart disease (binary)
#
# Goal: inform decision-making of cardiologists
#
# Model can inform, but should not make decisions. Specially in healthcare
#
# ![image.png](attachment:d5c7e3c6-ffd8-447d-bd8c-af432dbf4383.png)
#
# ## User Requirements
#
# The end user in our case study is CardioCare clinic. The requirement is a machine learning model that can predict the risk of heart disease **accurately** and **reliably** using patient health data. As such, *the model must match or exceed the performance of a human expert cardiologist*. It must generalize to unseen data outside of its training set, such as new patient data, returning timeous predictions whenever required - even in the middle of the night when the ML engineer is unavailable.
#
# The model design process should be **secure** - sensitive training data should be handled in a safe and private environment, and the deployed model should be monitored continuously and retrained whenever necessary.
#
# Finally, the model should also be as **interpretable** as possible: cardiologists should be able to understand the model's prediction, and disregard or overwrite it when necessary.
#
# # Data Collection
#
# Collect relevant data such as:
# - Age
# - Blood pressure
# - Sex
# - ...
# -
#
# Data can be from the **private** dataset of the company or from **public** sources.
#
# Data has to be understood along with its context. Are they any potential sources of bias on the data?
